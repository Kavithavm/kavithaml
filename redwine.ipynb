# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/ML/wine dataset')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# redwine.csv  whitewine.csv  winequality-red.csv  winequality-white.csv

# %%
train=pd.read_csv('redwine.csv')

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
train.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
import copy
train1=train.copy()

# %%
train.quantile(.25)
# Out:
# fixed acidity            7.1000
# volatile acidity         0.3900
# citric acid              0.0900
# residual sugar           1.9000
# chlorides                0.0700
# free sulfur dioxide      7.0000
# total sulfur dioxide    22.0000
# density                  0.9956
# pH                       3.2100
# sulphates                0.5500
# alcohol                  9.5000
# quality                  5.0000
# Name: 0.25, dtype: float64

# %%
train.quantile(.50)
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# Name: 0.5, dtype: float64

# %%
train.quantile(.75)
# Out:
# fixed acidity            9.200000
# volatile acidity         0.640000
# citric acid              0.420000
# residual sugar           2.600000
# chlorides                0.090000
# free sulfur dioxide     21.000000
# total sulfur dioxide    62.000000
# density                  0.997835
# pH                       3.400000
# sulphates                0.730000
# alcohol                 11.100000
# quality                  6.000000
# Name: 0.75, dtype: float64

# %%
#range
train.quantile(.75-.25)
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# Name: 0.5, dtype: float64

# %%
train.std()
# Out:
# fixed acidity            1.741096
# volatile acidity         0.179060
# citric acid              0.194801
# residual sugar           1.409928
# chlorides                0.047065
# free sulfur dioxide     10.460157
# total sulfur dioxide    32.895324
# density                  0.001887
# pH                       0.154386
# sulphates                0.169507
# alcohol                  1.065668
# quality                  0.807569
# dtype: float64

# %%
train.kurtosis()
# Out:
# fixed acidity            1.132143
# volatile acidity         1.225542
# citric acid             -0.788998
# residual sugar          28.617595
# chlorides               41.715787
# free sulfur dioxide      2.023562
# total sulfur dioxide     3.809824
# density                  0.934079
# pH                       0.806943
# sulphates               11.720251
# alcohol                  0.200029
# quality                  0.296708
# dtype: float64

# %%
train.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
train.var()
# Out:
# fixed acidity              3.031416
# volatile acidity           0.032062
# citric acid                0.037947
# residual sugar             1.987897
# chlorides                  0.002215
# free sulfur dioxide      109.414884
# total sulfur dioxide    1082.102373
# density                    0.000004
# pH                         0.023835
# sulphates                  0.028733
# alcohol                    1.135647
# quality                    0.652168
# dtype: float64

# %%
train.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
x1=train.drop(columns=['fixed acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'quality'])

# %%
x1
# Out:
#       volatile acidity  alcohol
# 0                0.700      9.4
# 1                0.880      9.8
# 2                0.760      9.8
# 3                0.280      9.8
# 4                0.700      9.4
# 5                0.660      9.4
# 6                0.600      9.4
# 7                0.650     10.0
# 8                0.580      9.5
# 9                0.500     10.5
# 10               0.580      9.2
# 11               0.500     10.5
# 12               0.615      9.9
# 13               0.610      9.1
# 14               0.620      9.2
# 15               0.620      9.2
# 16               0.280     10.5
# 17               0.560      9.3
# 18               0.590      9.0
# 19               0.320      9.2
# 20               0.220      9.4
# 21               0.390      9.7
# 22               0.430      9.5
# 23               0.490      9.4
# 24               0.400      9.7
# 25               0.390      9.3
# 26               0.410      9.5
# 27               0.430      9.5
# ...

# %%
train.alcohol.plot.kde()

# %%
import seaborn as sns
a2=sns.kdeplot(np.log(train['alcohol']))

# %%
np.sqrt(train['alcohol']).skew()
# Out:
# 0.7587508003569133

# %%
import seaborn as sns
train.plot.kde()

# %%
train.chlorides.plot.kde()

# %%
train.fixed acidity.plot.kde()
# Out:
#   File "<ipython-input-81-be458449a7ec>", line 1
#     train.fixed acidity.plot.kde()
#                       ^
# SyntaxError: invalid syntax

# %%
train.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9be39eb5f8>,
# ...
#       dtype=object)

# %%
train.boxplot()

# %%
#Bivariate Analysis
train.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

ax=sns.heatmap(train.corr())

# %%
y=train['quality']

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
train2=train.drop('quality',axis=1)

# %%
train.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
x1=
# Out:
#   File "<ipython-input-30-feab64158263>", line 1
#     x1=
#        ^
# SyntaxError: invalid syntax

# %%
x1.head()
# Out:
#    volatile acidity  alcohol
# 0              0.70      9.4
# 1              0.88      9.8
# 2              0.76      9.8
# 3              0.28      9.8
# 4              0.70      9.4

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.3,random_state=1)

# %%
x_train.head()
# Out:
#      volatile acidity  alcohol
# 126             1.330     10.9
# 810             0.490     10.5
# 635             0.840      9.7
# 598             0.585      9.8
# 880             0.560      9.9

# %%
x_train.shape
# Out:
# (1119, 2)

# %%
x_test.head()
# Out:
#       volatile acidity  alcohol
# 75                0.41     10.5
# 1283              0.63     10.2
# 408               0.34     11.3
# 1281              0.46     10.4
# 1118              0.39     13.3

# %%
x_test.shape
# Out:
# (480, 2)

# %%
y_train.head()
# Out:
# 126    5
# 810    5
# 635    5
# 598    6
# 880    5
# Name: quality, dtype: int64

# %%
y_train.shape
# Out:
# (1119,)

# %%
y_test.shape
# Out:
# (480,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(random_state=1)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.8936550491510277

# %%
rf.score(x_test,y_test)
# Out:
# 0.5583333333333333

# %%
rf=RandomForestClassifier(random_state=1,n_estimators=50,min_samples_split=4,)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=4,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.868632707774799

# %%
rf.score(x_test,y_test)
# Out:
# 0.5895833333333333

# %%
rf=RandomForestClassifier(random_state=1,n_estimators=300,min_samples_split=20,min_samples_leaf=4)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=20,
#             min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.6747095621090259

# %%
rf.score(x_test,y_test)
# Out:
# 0.5916666666666667

# %%
rf=RandomForestClassifier(random_state=1,n_estimators=300,min_samples_split=20,min_samples_leaf=6)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=6, min_samples_split=20,
#             min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.6604110813226095

# %%
rf.score(x_test,y_test)
# Out:
# 0.5791666666666667

# %%
from sklearn.model_selection import GridSearchCV
param_grid={
    'bootstrap':[True],
    'max_depth':[80,90,100,110],
    'max_features':[2,3,4,5],
    'min_samples_leaf':[3,4,5],
    'min_samples_split':[20,30,50,100,120],
    'n_estimators':[100,200,300,1000,2000]
}
rf=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=3,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 1200 candidates, totalling 3600 fits
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=100
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=100
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=100
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=200
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=20, n_estimators=100, total=   0.2s
# ...

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 2,
#  'min_samples_leaf': 3,
#  'min_samples_split': 20,
#  'n_estimators': 2000}

# %%
best_grid=grid_search.best_estimator_

# %%
best_grid
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=100, max_features=2, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3, min_samples_split=20,
#             min_weight_fraction_leaf=0.0, n_estimators=2000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
grid_search.best_score_
# Out:
# 0.6416443252904379

# %%
import xgboost as xgb
model=xgb.XGBRegressor()
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
model.score(x_train,y_train)
# Out:
# 0.6762874601144452

# %%
model=xgb.XGBRegressor(n_estimators=1000,min_child_weight=10,learning_rate=0.05,max_depth=5,reg_alpha=1,reg_lambda=1)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.05, max_delta_step=0,
#        max_depth=5, min_child_weight=10, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=1, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
model.score(x_train,y_train)
# Out:
# 0.966734798359602

# %%
model.score(x_test,y_test)
# Out:
# 0.3790364514038642

# %%
model=xgb.XGBRegressor(n_estimators=1000,min_child_weight=50,learning_rate=0.05,max_depth=5,reg_alpha=1,reg_lambda=1)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.05, max_delta_step=0,
#        max_depth=5, min_child_weight=50, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=1, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
model=xgb.XGBRegressor(n_estimators=3000,min_child_weight=70,learning_rate=0.05,max_depth=5,reg_alpha=1,reg_lambda=1)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.05, max_delta_step=0,
#        max_depth=5, min_child_weight=70, missing=None, n_estimators=3000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=1, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
model.score(x_train,y_train)
# Out:
# 0.9512986717307462

# %%
model.score(x_test,y_test)
# Out:
# 0.3596482172295019

# %%
x_train.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 126            8.2             1.330         0.00             1.7      0.081
# 810            7.3             0.490         0.10             2.6      0.068
# 635            8.7             0.840         0.00             1.4      0.065
# 598            8.5             0.585         0.18             2.1      0.078
# 880            9.2             0.560         0.18             1.6      0.078
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 126                  3.0                  12.0  0.99640  3.53       0.49
# 810                  4.0                  14.0  0.99562  3.30       0.47
# 635                 24.0                  33.0  0.99540  3.27       0.55
# 598                  5.0                  30.0  0.99670  3.20       0.48
# 880                 10.0                  21.0  0.99576  3.15       0.49
#
#      alcohol
# 126     10.9
# 810     10.5
# 635      9.7
# ...

# %%
train.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('volatile acidity', 'alcohol')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-0cd3603356f8> in <module>()
# ...
